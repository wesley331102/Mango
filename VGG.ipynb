# %%
# Update gdown
# !pip install --upgrade --no-cache-dir gdown

# Download the dataset from Google Drive
# !gdown --id '16FvOGDl-9cL1nOt0cKKJQvWWysMStTPX&export' --output data.zip
# !gdown --id '1ReuU9QWr5Da-VeTOQIFf-WvFZps1PVmW&export' --output yolo_data.zip

# Unzip the dataset.
# !unzip -o data.zip
# !unzip -o yolo_data.zip
# !ls
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: resultTrain/00877.jpg
#   inflating: resultTrain/00878.jpg
#   inflating: resultTrain/00879.jpg
#   inflating: resultTrain/00880.jpg
#   inflating: resultTrain/00881.jpg
#   inflating: resultTrain/00883.jpg
#   inflating: resultTrain/00885.jpg
#   inflating: resultTrain/00886.jpg
#   inflating: resultTrain/00887.jpg
#   inflating: resultTrain/00888.jpg
#   inflating: resultTrain/00889.jpg
#   inflating: resultTrain/00892.jpg
#   inflating: resultTrain/00893.jpg
#   inflating: resultTrain/00894.jpg
#   inflating: resultTrain/00895.jpg
#   inflating: resultTrain/00896.jpg
#   inflating: resultTrain/00897.jpg
#   inflating: resultTrain/00898.jpg
#   inflating: resultTrain/00899.jpg
#   inflating: resultTrain/00900.jpg
#   inflating: resultTrain/00901.jpg
#   inflating: resultTrain/00902.jpg
#   inflating: resultTrain/00903.jpg
#   inflating: resultTrain/00904.jpg
#   inflating: resultTrain/00905.jpg
#   inflating: resultTrain/00906.jpg
#   inflating: resultTrain/00907.jpg
#   inflating: resultTrain/00908.jpg
#   inflating: resultTrain/00912.jpg
#   inflating: resultTrain/00913.jpg
#   inflating: resultTrain/00914.jpg
#   inflating: resultTrain/00915.jpg
#   inflating: resultTrain/00916.jpg
#   inflating: resultTrain/00917.jpg
#   inflating: resultTrain/00918.jpg
#   inflating: resultTrain/00922.jpg
#   inflating: resultTrain/00923.jpg
#   inflating: resultTrain/00925.jpg
#   inflating: resultTrain/00926.jpg
#   inflating: resultTrain/00927.jpg
#   inflating: resultTrain/00928.jpg
#   inflating: resultTrain/00929.jpg
#   inflating: resultTrain/00932.jpg
#   inflating: resultTrain/00933.jpg
#   inflating: resultTrain/00934.jpg
#   inflating: resultTrain/00935.jpg
#   inflating: resultTrain/00936.jpg
#   inflating: resultTrain/00938.jpg
#   inflating: resultTrain/00940.jpg
#   inflating: resultTrain/00942.jpg
#   inflating: resultTrain/00943.jpg
#   inflating: resultTrain/00945.jpg
#   inflating: resultTrain/00950.jpg
#   inflating: resultTrain/00951.jpg
#   inflating: resultTrain/00953.jpg
#   inflating: resultTrain/00954.jpg
#   inflating: resultTrain/00955.jpg
#   inflating: resultTrain/00956.jpg
#   inflating: resultTrain/00957.jpg
#   inflating: resultTrain/00958.jpg
#   inflating: resultTrain/00960.jpg
#   inflating: resultTrain/00961.jpg
#   inflating: resultTrain/00963.jpg
#   inflating: resultTrain/00964.jpg
#   inflating: resultTrain/00965.jpg
#   inflating: resultTrain/00966.jpg
#   inflating: resultTrain/00968.jpg
#   inflating: resultTrain/00970.jpg
#   inflating: resultTrain/00972.jpg
#   inflating: resultTrain/00973.jpg
#   inflating: resultTrain/00974.jpg
#   inflating: resultTrain/00975.jpg
#   inflating: resultTrain/00976.jpg
#   inflating: resultTrain/00977.jpg
#   inflating: resultTrain/00978.jpg
#   inflating: resultTrain/00979.jpg
#   inflating: resultTrain/00982.jpg
#   inflating: resultTrain/00984.jpg
#   inflating: resultTrain/00985.jpg
#   inflating: resultTrain/00986.jpg
#   inflating: resultTrain/00988.jpg
#   inflating: resultTrain/00989.jpg
#   inflating: resultTrain/00990.jpg
#   inflating: resultTrain/00992.jpg
#   inflating: resultTrain/00994.jpg
#   inflating: resultTrain/00995.jpg
#   inflating: resultTrain/00996.jpg
#   inflating: resultTrain/00997.jpg
#   inflating: resultTrain/00998.jpg
#   inflating: resultTrain/00999.jpg
#   inflating: resultTrain/01001.jpg
#   inflating: resultTrain/01002.jpg
#   inflating: resultTrain/01004.jpg
#   inflating: resultTrain/01006.jpg
#   inflating: resultTrain/01007.jpg
#   inflating: resultTrain/01009.jpg
#   inflating: resultTrain/01011.jpg
#   inflating: resultTrain/01012.jpg
#   inflating: resultTrain/01014.jpg
#   inflating: resultTrain/01016.jpg
#   inflating: resultTrain/01017.jpg
#   inflating: resultTrain/01018.jpg
#   inflating: resultTrain/01019.jpg
#   inflating: resultTrain/01021.jpg
#   inflating: resultTrain/01022.jpg
#   inflating: resultTrain/01025.jpg
#   inflating: resultTrain/01026.jpg
#   inflating: resultTrain/01027.jpg
#   inflating: resultTrain/01028.jpg
#   inflating: resultTrain/01030.jpg
#   inflating: resultTrain/01032.jpg
#   inflating: resultTrain/01033.jpg
#   inflating: resultTrain/01034.jpg
#   inflating: resultTrain/01035.jpg
#   inflating: resultTrain/01036.jpg
#   inflating: resultTrain/01037.jpg
#   inflating: resultTrain/01039.jpg
#   inflating: resultTrain/01040.jpg
#   inflating: resultTrain/01042.jpg
#   inflating: resultTrain/01043.jpg
#   inflating: resultTrain/01044.jpg
#   inflating: resultTrain/01046.jpg
#   inflating: resultTrain/01047.jpg
#   inflating: resultTrain/01050.jpg
#   inflating: resultTrain/01051.jpg
#   inflating: resultTrain/01052.jpg
#   inflating: resultTrain/01053.jpg
#   inflating: resultTrain/01054.jpg
#   inflating: resultTrain/01055.jpg
#   inflating: resultTrain/01057.jpg
#   inflating: resultTrain/01058.jpg
#   inflating: resultTrain/01059.jpg
#   inflating: resultTrain/01060.jpg
#   inflating: resultTrain/01062.jpg
#   inflating: resultTrain/01065.jpg
#   inflating: resultTrain/01066.jpg
#   inflating: resultTrain/01068.jpg
#   inflating: resultTrain/01070.jpg
#   inflating: resultTrain/01071.jpg
#   inflating: resultTrain/01072.jpg
#   inflating: resultTrain/01073.jpg
#   inflating: resultTrain/01074.jpg
#   inflating: resultTrain/01078.jpg
#   inflating: resultTrain/01080.jpg
#   inflating: resultTrain/01081.jpg
#   inflating: resultTrain/01082.jpg
#   inflating: resultTrain/01083.jpg
#   inflating: resultTrain/01084.jpg
#   inflating: resultTrain/01085.jpg
#   inflating: resultTrain/01086.jpg
#   inflating: resultTrain/01087.jpg
#   inflating: resultTrain/01091.jpg
#   inflating: resultTrain/01093.jpg
#   inflating: resultTrain/01094.jpg
#   inflating: resultTrain/01096.jpg
#   inflating: resultTrain/01098.jpg
#   inflating: resultTrain/01099.jpg
#   inflating: resultTrain/01100.jpg
#   inflating: resultTrain/01101.jpg
#   inflating: resultTrain/01103.jpg
#   inflating: resultTrain/01104.jpg
#   inflating: resultTrain/01105.jpg
#   inflating: resultTrain/01109.jpg
#   inflating: resultTrain/01117.jpg
#   inflating: resultTrain/01118.jpg
#   inflating: resultTrain/01119.jpg
#   inflating: resultTrain/01121.jpg
#   inflating: resultTrain/01125.jpg
#   inflating: resultTrain/01126.jpg
#   inflating: resultTrain/01127.jpg
#   inflating: resultTrain/01128.jpg
#   inflating: resultTrain/01129.jpg
#   inflating: resultTrain/01131.jpg
#   inflating: resultTrain/01132.jpg
#   inflating: resultTrain/01133.jpg
#   inflating: resultTrain/01136.jpg
#   inflating: resultTrain/01140.jpg
#   inflating: resultTrain/01141.jpg
#   inflating: resultTrain/01143.jpg
#   inflating: resultTrain/01144.jpg
#   inflating: resultTrain/01145.jpg
#   inflating: resultTrain/01146.jpg
#   inflating: resultTrain/01147.jpg
#   inflating: resultTrain/01148.jpg
#   inflating: resultTrain/01149.jpg
#   inflating: resultTrain/01150.jpg
#   inflating: resultTrain/01151.jpg
#   inflating: resultTrain/01153.jpg
#   inflating: resultTrain/01154.jpg
#   inflating: resultTrain/01155.jpg
#   inflating: resultTrain/01156.jpg
#   inflating: resultTrain/01157.jpg
#   inflating: resultTrain/01159.jpg
#   inflating: resultTrain/01160.jpg
#   inflating: resultTrain/01161.jpg
#   inflating: resultTrain/01162.jpg
#   inflating: resultTrain/01164.jpg
#   inflating: resultTrain/01166.jpg
#   inflating: resultTrain/01167.jpg
#   inflating: resultTrain/01168.jpg
#   inflating: resultTrain/01170.jpg
#   inflating: resultTrain/01171.jpg
#   inflating: resultTrain/01173.jpg
#   inflating: resultTrain/01176.jpg
#   inflating: resultTrain/01177.jpg
#   inflating: resultTrain/01178.jpg
#   inflating: resultTrain/01179.jpg
#   inflating: resultTrain/01180.jpg
#   inflating: resultTrain/01181.jpg
#   inflating: resultTrain/01182.jpg
#   inflating: resultTrain/01183.jpg
#   inflating: resultTrain/01185.jpg
#   inflating: resultTrain/01186.jpg
#   inflating: resultTrain/01187.jpg
#   inflating: resultTrain/01189.jpg
#   inflating: resultTrain/01190.jpg
#   inflating: resultTrain/01191.jpg
#   inflating: resultTrain/01192.jpg
#   inflating: resultTrain/01194.jpg
#   inflating: resultTrain/01195.jpg
#   inflating: resultTrain/01196.jpg
#   inflating: resultTrain/01198.jpg
#   inflating: resultTrain/01199.jpg
#   inflating: resultTrain/01202.jpg
#   inflating: resultTrain/01203.jpg
#   inflating: resultTrain/01205.jpg
#   inflating: resultTrain/01207.jpg
#   inflating: resultTrain/01209.jpg
#   inflating: resultTrain/01210.jpg
#   inflating: resultTrain/01211.jpg
#   inflating: resultTrain/01212.jpg
#   inflating: resultTrain/01214.jpg
#   inflating: resultTrain/01215.jpg
#   inflating: resultTrain/01216.jpg
#   inflating: resultTrain/01220.jpg
#   inflating: resultTrain/01221.jpg
#   inflating: resultTrain/01222.jpg
#   inflating: resultTrain/01225.jpg
#   inflating: resultTrain/01226.jpg
#   inflating: resultTrain/01227.jpg
#   inflating: resultTrain/01229.jpg
#   inflating: resultTrain/01231.jpg
#   inflating: resultTrain/01233.jpg
#   inflating: resultTrain/01234.jpg
#   inflating: resultTrain/01239.jpg
#   inflating: resultTrain/01240.jpg
#   inflating: resultTrain/01241.jpg
#   inflating: resultTrain/01242.jpg
#   inflating: resultTrain/01243.jpg
#   inflating: resultTrain/01244.jpg
#   inflating: resultTrain/01245.jpg
#   inflating: resultTrain/01247.jpg
#   inflating: resultTrain/01249.jpg
#   inflating: resultTrain/01250.jpg
#   inflating: resultTrain/01252.jpg
#   inflating: resultTrain/01253.jpg
#   inflating: resultTrain/01254.jpg
#   inflating: resultTrain/01255.jpg
#   inflating: resultTrain/01256.jpg
#   inflating: resultTrain/01257.jpg
#   inflating: resultTrain/01258.jpg
#   inflating: resultTrain/01262.jpg
#   inflating: resultTrain/01263.jpg
#   inflating: resultTrain/01264.jpg
#   inflating: resultTrain/01266.jpg
#   inflating: resultTrain/01268.jpg
#   inflating: resultTrain/01269.jpg
#   inflating: resultTrain/01270.jpg
#   inflating: resultTrain/01271.jpg
#   inflating: resultTrain/01272.jpg
#   inflating: resultTrain/01275.jpg
#   inflating: resultTrain/01276.jpg
#   inflating: resultTrain/01278.jpg
#   inflating: resultTrain/01280.jpg
#   inflating: resultTrain/01281.jpg
#   inflating: resultTrain/01283.jpg
#   inflating: resultTrain/01284.jpg
#   inflating: resultTrain/01285.jpg
#   inflating: resultTrain/01286.jpg
#   inflating: resultTrain/01287.jpg
#   inflating: resultTrain/01288.jpg
#   inflating: resultTrain/01289.jpg
#   inflating: resultTrain/01290.jpg
#   inflating: resultTrain/01291.jpg
#   inflating: resultTrain/01292.jpg
#   inflating: resultTrain/01295.jpg
#   inflating: resultTrain/01296.jpg
#   inflating: resultTrain/01297.jpg
#   inflating: resultTrain/01298.jpg
#   inflating: resultTrain/01299.jpg
#   inflating: resultTrain/01301.jpg
#   inflating: resultTrain/01302.jpg
#   inflating: resultTrain/01303.jpg
#   inflating: resultTrain/01304.jpg
#   inflating: resultTrain/01305.jpg
#   inflating: resultTrain/01306.jpg
#   inflating: resultTrain/01307.jpg
#   inflating: resultTrain/01308.jpg
#   inflating: resultTrain/01309.jpg
#   inflating: resultTrain/01310.jpg
#   inflating: resultTrain/01312.jpg
#   inflating: resultTrain/01313.jpg
#   inflating: resultTrain/01314.jpg
#   inflating: resultTrain/01317.jpg
#   inflating: resultTrain/01318.jpg
#   inflating: resultTrain/01319.jpg
#   inflating: resultTrain/01320.jpg
#   inflating: resultTrain/01321.jpg
#   inflating: resultTrain/01323.jpg
#   inflating: resultTrain/01325.jpg
#   inflating: resultTrain/01327.jpg
#   inflating: resultTrain/01328.jpg
#   inflating: resultTrain/01329.jpg
#   inflating: resultTrain/01331.jpg
#   inflating: resultTrain/01332.jpg
#   inflating: resultTrain/01333.jpg
#   inflating: resultTrain/01334.jpg
#   inflating: resultTrain/01335.jpg
#   inflating: resultTrain/01337.jpg
#   inflating: resultTrain/01338.jpg
#   inflating: resultTrain/01340.jpg
#   inflating: resultTrain/01341.jpg
#   inflating: resultTrain/01342.jpg
#   inflating: resultTrain/01343.jpg
#   inflating: resultTrain/01345.jpg
#   inflating: resultTrain/01347.jpg
#   inflating: resultTrain/01351.jpg
#   inflating: resultTrain/01353.jpg
#   inflating: resultTrain/01354.jpg
#   inflating: resultTrain/01355.jpg
#   inflating: resultTrain/01356.jpg
#   inflating: resultTrain/01357.jpg
#   inflating: resultTrain/01358.jpg
#   inflating: resultTrain/01359.jpg
#   inflating: resultTrain/01361.jpg
#   inflating: resultTrain/01362.jpg
#   inflating: resultTrain/01364.jpg
#   inflating: resultTrain/01366.jpg
#   inflating: resultTrain/01367.jpg
#   inflating: resultTrain/01368.jpg
#   inflating: resultTrain/01370.jpg
#   inflating: resultTrain/01371.jpg
#   inflating: resultTrain/01372.jpg
#   inflating: resultTrain/01374.jpg
#   inflating: resultTrain/01376.jpg
#   inflating: resultTrain/01378.jpg
#   inflating: resultTrain/01379.jpg
#   inflating: resultTrain/01381.jpg
#   inflating: resultTrain/01382.jpg
#   inflating: resultTrain/01383.jpg
#   inflating: resultTrain/01384.jpg
#   inflating: resultTrain/01385.jpg
#   inflating: resultTrain/01386.jpg
#   inflating: resultTrain/01387.jpg
#   inflating: resultTrain/01388.jpg
#   inflating: resultTrain/01389.jpg
#   inflating: resultTrain/01391.jpg
#   inflating: resultTrain/01392.jpg
#   inflating: resultTrain/01393.jpg
#   inflating: resultTrain/01394.jpg
#   inflating: resultTrain/01395.jpg
#   inflating: resultTrain/01396.jpg
#   inflating: resultTrain/01397.jpg
#   inflating: resultTrain/01400.jpg
#   inflating: resultTrain/01403.jpg
#   inflating: resultTrain/01404.jpg
#   inflating: resultTrain/01405.jpg
#   inflating: resultTrain/01406.jpg
#   inflating: resultTrain/01407.jpg
#   inflating: resultTrain/01408.jpg
#   inflating: resultTrain/01411.jpg
#   inflating: resultTrain/01412.jpg
#   inflating: resultTrain/01413.jpg
#   inflating: resultTrain/01414.jpg
#   inflating: resultTrain/01415.jpg
#   inflating: resultTrain/01417.jpg
#   inflating: resultTrain/01418.jpg
#   inflating: resultTrain/01419.jpg
#   inflating: resultTrain/01420.jpg
#   inflating: resultTrain/01421.jpg
#   inflating: resultTrain/01425.jpg
#   inflating: resultTrain/01426.jpg
#   inflating: resultTrain/01427.jpg
#   inflating: resultTrain/01428.jpg
#   inflating: resultTrain/01429.jpg
#   inflating: resultTrain/01430.jpg
#   inflating: resultTrain/01431.jpg
#   inflating: resultTrain/01432.jpg
#   inflating: resultTrain/01433.jpg
#   inflating: resultTrain/01434.jpg
#   inflating: resultTrain/01436.jpg
#   inflating: resultTrain/01438.jpg
#   inflating: resultTrain/01440.jpg
#   inflating: resultTrain/01441.jpg
#   inflating: resultTrain/01442.jpg
#   inflating: resultTrain/01443.jpg
#   inflating: resultTrain/01445.jpg
#   inflating: resultTrain/01446.jpg
#   inflating: resultTrain/01449.jpg
#   inflating: resultTrain/01451.jpg
#   inflating: resultTrain/01452.jpg
#   inflating: resultTrain/01454.jpg
#   inflating: resultTrain/01455.jpg
#   inflating: resultTrain/01457.jpg
#   inflating: resultTrain/01459.jpg
#   inflating: resultTrain/01460.jpg
#   inflating: resultTrain/01462.jpg
#   inflating: resultTrain/01463.jpg
#   inflating: resultTrain/01465.jpg
#   inflating: resultTrain/01466.jpg
#   inflating: resultTrain/01467.jpg
#   inflating: resultTrain/01469.jpg
#   inflating: resultTrain/01471.jpg
#   inflating: resultTrain/01472.jpg
#   inflating: resultTrain/01473.jpg
#   inflating: resultTrain/01475.jpg
#   inflating: resultTrain/01476.jpg
#   inflating: resultTrain/01478.jpg
#   inflating: resultTrain/01479.jpg
#   inflating: resultTrain/01480.jpg
#   inflating: resultTrain/01486.jpg
#   inflating: resultTrain/01487.jpg
#   inflating: resultTrain/01489.jpg
#   inflating: resultTrain/01490.jpg
#   inflating: resultTrain/01491.jpg
#   inflating: resultTrain/01492.jpg
#   inflating: resultTrain/01493.jpg
#   inflating: resultTrain/01494.jpg
#   inflating: resultTrain/01496.jpg
#   inflating: resultTrain/01497.jpg
#   inflating: resultTrain/01499.jpg
#   inflating: resultTrain/01501.jpg
#   inflating: resultTrain/01502.jpg
#   inflating: resultTrain/01504.jpg
#   inflating: resultTrain/01506.jpg
#   inflating: resultTrain/01508.jpg
#   inflating: resultTrain/01509.jpg
#   inflating: resultTrain/01510.jpg
#   inflating: resultTrain/01513.jpg
#   inflating: resultTrain/01514.jpg
#   inflating: resultTrain/01515.jpg
#   inflating: resultTrain/01516.jpg
#   inflating: resultTrain/01517.jpg
#   inflating: resultTrain/01518.jpg
#   inflating: resultTrain/01520.jpg
#   inflating: resultTrain/01522.jpg
#   inflating: resultTrain/01525.jpg
#   inflating: resultTrain/01526.jpg
#   inflating: resultTrain/01527.jpg
#   inflating: resultTrain/01528.jpg
#   inflating: resultTrain/01529.jpg
#   inflating: resultTrain/01530.jpg
#   inflating: resultTrain/01532.jpg
#   inflating: resultTrain/01533.jpg
#   inflating: resultTrain/01534.jpg
#   inflating: resultTrain/01536.jpg
#   inflating: resultTrain/01538.jpg
#   inflating: resultTrain/01540.jpg
#   inflating: resultTrain/01541.jpg
#   inflating: resultTrain/01542.jpg
#   inflating: resultTrain/01543.jpg
#   inflating: resultTrain/01544.jpg
#   inflating: resultTrain/01545.jpg
#   inflating: resultTrain/01546.jpg
#   inflating: resultTrain/01547.jpg
#   inflating: resultTrain/01549.jpg
#   inflating: resultTrain/01551.jpg
#   inflating: resultTrain/01552.jpg
#   inflating: resultTrain/01553.jpg
#   inflating: resultTrain/01555.jpg
#   inflating: resultTrain/01556.jpg
#   inflating: resultTrain/01557.jpg
#   inflating: resultTrain/01558.jpg
#   inflating: resultTrain/01560.jpg
#   inflating: resultTrain/01561.jpg
#   inflating: resultTrain/01563.jpg
#   inflating: resultTrain/01564.jpg
#   inflating: resultTrain/01566.jpg
#   inflating: resultTrain/01568.jpg
#   inflating: resultTrain/01569.jpg
#   inflating: resultTrain/01571.jpg
#   inflating: resultTrain/01572.jpg
#   inflating: resultTrain/01574.jpg
#   inflating: resultTrain/01575.jpg
#   inflating: resultTrain/01577.jpg
#   inflating: resultTrain/01578.jpg
#   inflating: resultTrain/01579.jpg
#   inflating: resultTrain/01580.jpg
#   inflating: resultTrain/01581.jpg
#   inflating: resultTrain/01582.jpg
#   inflating: resultTrain/01583.jpg
#   inflating: resultTrain/01584.jpg
#   inflating: resultTrain/01585.jpg
#   inflating: resultTrain/01586.jpg
#   inflating: resultTrain/01587.jpg
#   inflating: resultTrain/01588.jpg
#   inflating: resultTrain/01592.jpg
#   inflating: resultTrain/01593.jpg
#   inflating: resultTrain/01594.jpg
#   inflating: resultTrain/01595.jpg
#   inflating: resultTrain/01596.jpg
#   inflating: resultTrain/01597.jpg
#   inflating: resultTrain/01598.jpg
#   inflating: resultTrain/01599.jpg
#   inflating: resultTrain/01600.jpg
#   inflating: resultTrain/01601.jpg
#   inflating: resultTrain/01606.jpg
#   inflating: resultTrain/01607.jpg
#   inflating: resultTrain/01608.jpg
#   inflating: resultTrain/01609.jpg
#   inflating: resultTrain/01611.jpg
#   inflating: resultTrain/01612.jpg
#   inflating: resultTrain/01613.jpg
#   inflating: resultTrain/01614.jpg
#   inflating: resultTrain/01617.jpg
#   inflating: resultTrain/01618.jpg
#   inflating: resultTrain/01619.jpg
#   inflating: resultTrain/01622.jpg
#   inflating: resultTrain/01624.jpg
#   inflating: resultTrain/01625.jpg
#   inflating: resultTrain/01626.jpg
#   inflating: resultTrain/01627.jpg
#   inflating: resultTrain/01628.jpg
#   inflating: resultTrain/01629.jpg
#   inflating: resultTrain/01630.jpg
#   inflating: resultTrain/01631.jpg
#   inflating: resultTrain/01632.jpg
#   inflating: resultTrain/01633.jpg
#   inflating: resultTrain/01634.jpg
#   inflating: resultTrain/01637.jpg
#   inflating: resultTrain/01638.jpg
#   inflating: resultTrain/01639.jpg
#   inflating: resultTrain/01641.jpg
#   inflating: resultTrain/01642.jpg
#   inflating: resultTrain/01643.jpg
#   inflating: resultTrain/01644.jpg
#   inflating: resultTrain/01646.jpg
#   inflating: resultTrain/01647.jpg
#   inflating: resultTrain/01648.jpg
#   inflating: resultTrain/01650.jpg
#   inflating: resultTrain/01651.jpg
#   inflating: resultTrain/01654.jpg
#   inflating: resultTrain/01658.jpg
#   inflating: resultTrain/01659.jpg
#   inflating: resultTrain/01661.jpg
#   inflating: resultTrain/01663.jpg
#   inflating: resultTrain/01664.jpg
#   inflating: resultTrain/01665.jpg
#   inflating: resultTrain/01667.jpg
#   inflating: resultTrain/01668.jpg
#   inflating: resultTrain/01670.jpg
#   inflating: resultTrain/01672.jpg
#   inflating: resultTrain/01674.jpg
#   inflating: resultTrain/01675.jpg
#   inflating: resultTrain/01676.jpg
#   inflating: resultTrain/01677.jpg
#   inflating: resultTrain/01680.jpg
#   inflating: resultTrain/01685.jpg
#   inflating: resultTrain/01686.jpg
#   inflating: resultTrain/01689.jpg
#   inflating: resultTrain/01691.jpg
#   inflating: resultTrain/01695.jpg
#   inflating: resultTrain/01696.jpg
#   inflating: resultTrain/01697.jpg
#   inflating: resultTrain/01701.jpg
#   inflating: resultTrain/01702.jpg
#   inflating: resultTrain/01703.jpg
#   inflating: resultTrain/01704.jpg
#   inflating: resultTrain/01706.jpg
#   inflating: resultTrain/01707.jpg
#   inflating: resultTrain/01708.jpg
#   inflating: resultTrain/01710.jpg
#   inflating: resultTrain/01711.jpg
#   inflating: resultTrain/01712.jpg
#   inflating: resultTrain/01713.jpg
#   inflating: resultTrain/01714.jpg
#   inflating: resultTrain/01715.jpg
#   inflating: resultTrain/01716.jpg
#   inflating: resultTrain/01717.jpg
#   inflating: resultTrain/01718.jpg
#   inflating: resultTrain/01719.jpg
#   inflating: resultTrain/01720.jpg
#   inflating: resultTrain/01721.jpg
#   inflating: resultTrain/01723.jpg
#   inflating: resultTrain/01724.jpg
#   inflating: resultTrain/01725.jpg
#   inflating: resultTrain/01726.jpg
#   inflating: resultTrain/01727.jpg
#   inflating: resultTrain/01728.jpg
#   inflating: resultTrain/01729.jpg
#   inflating: resultTrain/01730.jpg
#   inflating: resultTrain/01731.jpg
#   inflating: resultTrain/01732.jpg
#   inflating: resultTrain/01733.jpg
#   inflating: resultTrain/01734.jpg
#   inflating: resultTrain/01737.jpg
#   inflating: resultTrain/01739.jpg
#   inflating: resultTrain/01740.jpg
#   inflating: resultTrain/01741.jpg
#   inflating: resultTrain/01742.jpg
#   inflating: resultTrain/01744.jpg
#   inflating: resultTrain/01745.jpg
#   inflating: resultTrain/01746.jpg
#   inflating: resultTrain/01749.jpg
#   inflating: resultTrain/01752.jpg
#   inflating: resultTrain/01753.jpg
#   inflating: resultTrain/01754.jpg
#   inflating: resultTrain/01756.jpg
#   inflating: resultTrain/01758.jpg
#   inflating: resultTrain/01759.jpg
#   inflating: resultTrain/01760.jpg
#   inflating: resultTrain/01762.jpg
#   inflating: resultTrain/01763.jpg
#   inflating: resultTrain/01764.jpg
#   inflating: resultTrain/01765.jpg
#   inflating: resultTrain/01766.jpg
#   inflating: resultTrain/01767.jpg
#   inflating: resultTrain/01768.jpg
#   inflating: resultTrain/01770.jpg
#   inflating: resultTrain/01771.jpg
#   inflating: resultTrain/01773.jpg
#   inflating: resultTrain/01774.jpg
#   inflating: resultTrain/01777.jpg
#   inflating: resultTrain/01778.jpg
#   inflating: resultTrain/01780.jpg
#   inflating: resultTrain/01781.jpg
#   inflating: resultTrain/01782.jpg
#   inflating: resultTrain/01783.jpg
#   inflating: resultTrain/01784.jpg
#   inflating: resultTrain/01785.jpg
#   inflating: resultTrain/01786.jpg
#   inflating: resultTrain/01788.jpg
#   inflating: resultTrain/01789.jpg
#   inflating: resultTrain/01791.jpg
#   inflating: resultTrain/01792.jpg
#   inflating: resultTrain/01793.jpg
#   inflating: resultTrain/01794.jpg
#   inflating: resultTrain/01796.jpg
#   inflating: resultTrain/01797.jpg
#   inflating: resultTrain/01798.jpg
#   inflating: resultTrain/01801.jpg
#   inflating: resultTrain/01803.jpg
#   inflating: resultTrain/01804.jpg
#   inflating: resultTrain/01807.jpg
#   inflating: resultTrain/01808.jpg
#   inflating: resultTrain/01809.jpg
#   inflating: resultTrain/01810.jpg
#   inflating: resultTrain/01811.jpg
#   inflating: resultTrain/01812.jpg
#   inflating: resultTrain/01813.jpg
#   inflating: resultTrain/01814.jpg
#   inflating: resultTrain/01815.jpg
#   inflating: resultTrain/01816.jpg
#   inflating: resultTrain/01818.jpg
#   inflating: resultTrain/01819.jpg
#   inflating: resultTrain/01820.jpg
#   inflating: resultTrain/01821.jpg
#   inflating: resultTrain/01823.jpg
#   inflating: resultTrain/01824.jpg
#   inflating: resultTrain/01826.jpg
#   inflating: resultTrain/01827.jpg
#   inflating: resultTrain/01829.jpg
#   inflating: resultTrain/01831.jpg
#   inflating: resultTrain/01832.jpg
#   inflating: resultTrain/01834.jpg
#   inflating: resultTrain/01835.jpg
#   inflating: resultTrain/01836.jpg
#   inflating: resultTrain/01837.jpg
#   inflating: resultTrain/01838.jpg
#   inflating: resultTrain/01839.jpg
#   inflating: resultTrain/01840.jpg
#   inflating: resultTrain/01843.jpg
#   inflating: resultTrain/01845.jpg
#   inflating: resultTrain/01846.jpg
#   inflating: resultTrain/01850.jpg
#   inflating: resultTrain/01853.jpg
#   inflating: resultTrain/01854.jpg
#   inflating: resultTrain/01855.jpg
#   inflating: resultTrain/01856.jpg
#   inflating: resultTrain/01857.jpg
#   inflating: resultTrain/01861.jpg
#   inflating: resultTrain/01863.jpg
#   inflating: resultTrain/01865.jpg
#   inflating: resultTrain/01866.jpg
#   inflating: resultTrain/01867.jpg
#   inflating: resultTrain/01868.jpg
#   inflating: resultTrain/01869.jpg
#   inflating: resultTrain/01870.jpg
#   inflating: resultTrain/01871.jpg
#   inflating: resultTrain/01872.jpg
#   inflating: resultTrain/01874.jpg
#   inflating: resultTrain/01875.jpg
#   inflating: resultTrain/01876.jpg
#   inflating: resultTrain/01878.jpg
#   inflating: resultTrain/01879.jpg
#   inflating: resultTrain/01880.jpg
#   inflating: resultTrain/01881.jpg
#   inflating: resultTrain/01882.jpg
#   inflating: resultTrain/01885.jpg
#   inflating: resultTrain/01886.jpg
#   inflating: resultTrain/01887.jpg
#   inflating: resultTrain/01889.jpg
#   inflating: resultTrain/01890.jpg
#   inflating: resultTrain/01892.jpg
#   inflating: resultTrain/01893.jpg
#   inflating: resultTrain/01897.jpg
#   inflating: resultTrain/01898.jpg
#   inflating: resultTrain/01899.jpg
#   inflating: resultTrain/01900.jpg
#   inflating: resultTrain/01901.jpg
#   inflating: resultTrain/01902.jpg
#   inflating: resultTrain/01903.jpg
#   inflating: resultTrain/01904.jpg
#   inflating: resultTrain/01905.jpg
#   inflating: resultTrain/01907.jpg
#   inflating: resultTrain/01908.jpg
#   inflating: resultTrain/01909.jpg
#   inflating: resultTrain/01910.jpg
#   inflating: resultTrain/01911.jpg
#   inflating: resultTrain/01912.jpg
#   inflating: resultTrain/01913.jpg
#   inflating: resultTrain/01914.jpg
#   inflating: resultTrain/01915.jpg
#   inflating: resultTrain/01916.jpg
#   inflating: resultTrain/01919.jpg
#   inflating: resultTrain/01920.jpg
#   inflating: resultTrain/01921.jpg
#   inflating: resultTrain/01923.jpg
#   inflating: resultTrain/01926.jpg
#   inflating: resultTrain/01927.jpg
#   inflating: resultTrain/01928.jpg
#   inflating: resultTrain/01930.jpg
#   inflating: resultTrain/01931.jpg
#   inflating: resultTrain/01932.jpg
#   inflating: resultTrain/01933.jpg
#   inflating: resultTrain/01934.jpg
#   inflating: resultTrain/01935.jpg
#   inflating: resultTrain/01936.jpg
#   inflating: resultTrain/01937.jpg
#   inflating: resultTrain/01938.jpg
#   inflating: resultTrain/01940.jpg
#   inflating: resultTrain/01943.jpg
#   inflating: resultTrain/01945.jpg
#   inflating: resultTrain/01946.jpg
#   inflating: resultTrain/01947.jpg
#   inflating: resultTrain/01948.jpg
#   inflating: resultTrain/01949.jpg
#   inflating: resultTrain/01950.jpg
#   inflating: resultTrain/01951.jpg
#   inflating: resultTrain/01952.jpg
#   inflating: resultTrain/01954.jpg
#   inflating: resultTrain/01958.jpg
#   inflating: resultTrain/01959.jpg
#   inflating: resultTrain/01960.jpg
#   inflating: resultTrain/01961.jpg
#   inflating: resultTrain/01962.jpg
#   inflating: resultTrain/01964.jpg
#   inflating: resultTrain/01967.jpg
#   inflating: resultTrain/01968.jpg
#   inflating: resultTrain/01970.jpg
#   inflating: resultTrain/01971.jpg
#   inflating: resultTrain/01972.jpg
#   inflating: resultTrain/01974.jpg
#   inflating: resultTrain/01975.jpg
#   inflating: resultTrain/01976.jpg
#   inflating: resultTrain/01977.jpg
#   inflating: resultTrain/01978.jpg
#   inflating: resultTrain/01979.jpg
#   inflating: resultTrain/01981.jpg
#   inflating: resultTrain/01982.jpg
#   inflating: resultTrain/01983.jpg
#   inflating: resultTrain/01984.jpg
#   inflating: resultTrain/01985.jpg
#   inflating: resultTrain/01986.jpg
#   inflating: resultTrain/01987.jpg
#   inflating: resultTrain/01988.jpg
#   inflating: resultTrain/01990.jpg
#   inflating: resultTrain/01994.jpg
#   inflating: resultTrain/01995.jpg
#   inflating: resultTrain/01996.jpg
#   inflating: resultTrain/02000.jpg
#   inflating: resultTrain/02001.jpg
#   inflating: resultTrain/02002.jpg
#   inflating: resultTrain/02004.jpg
#   inflating: resultTrain/02005.jpg
#   inflating: resultTrain/02006.jpg
#   inflating: resultTrain/02007.jpg
#   inflating: resultTrain/02008.jpg
#   inflating: resultTrain/02009.jpg
#   inflating: resultTrain/02010.jpg
#   inflating: resultTrain/02012.jpg
#   inflating: resultTrain/02014.jpg
#   inflating: resultTrain/02017.jpg
#   inflating: resultTrain/02018.jpg
#   inflating: resultTrain/02020.jpg
#   inflating: resultTrain/02021.jpg
#   inflating: resultTrain/02022.jpg
#   inflating: resultTrain/02023.jpg
#   inflating: resultTrain/02024.jpg
#   inflating: resultTrain/02025.jpg
#   inflating: resultTrain/02026.jpg
#   inflating: resultTrain/02029.jpg
#   inflating: resultTrain/02030.jpg
#   inflating: resultTrain/02031.jpg
#   inflating: resultTrain/02033.jpg
#   inflating: resultTrain/02034.jpg
#   inflating: resultTrain/02035.jpg
#   inflating: resultTrain/02036.jpg
#   inflating: resultTrain/02037.jpg
#   inflating: resultTrain/02038.jpg
#   inflating: resultTrain/02039.jpg
#   inflating: resultTrain/02041.jpg
#   inflating: resultTrain/02042.jpg
#   inflating: resultTrain/02045.jpg
#   inflating: resultTrain/02046.jpg
#   inflating: resultTrain/02047.jpg
#   inflating: resultTrain/02048.jpg
#   inflating: resultTrain/02049.jpg
#   inflating: resultTrain/02050.jpg
#   inflating: resultTrain/02051.jpg
#   inflating: resultTrain/02052.jpg
#   inflating: resultTrain/02053.jpg
#   inflating: resultTrain/02054.jpg
#   inflating: resultTrain/02055.jpg
#   inflating: resultTrain/02056.jpg
#   inflating: resultTrain/02057.jpg
#   inflating: resultTrain/02060.jpg
#   inflating: resultTrain/02061.jpg
#   inflating: resultTrain/02062.jpg
#   inflating: resultTrain/02063.jpg
#   inflating: resultTrain/02064.jpg
#   inflating: resultTrain/02065.jpg
#   inflating: resultTrain/02066.jpg
#   inflating: resultTrain/02070.jpg
#   inflating: resultTrain/02071.jpg
#   inflating: resultTrain/02072.jpg
#   inflating: resultTrain/02077.jpg
#   inflating: resultTrain/02079.jpg
#   inflating: resultTrain/02080.jpg
#   inflating: resultTrain/02081.jpg
#   inflating: resultTrain/02082.jpg
#   inflating: resultTrain/02083.jpg
#   inflating: resultTrain/02084.jpg
#   inflating: resultTrain/02085.jpg
#   inflating: resultTrain/02086.jpg
#   inflating: resultTrain/02087.jpg
#   inflating: resultTrain/02088.jpg
#   inflating: resultTrain/02090.jpg
#   inflating: resultTrain/02092.jpg
#   inflating: resultTrain/02093.jpg
#   inflating: resultTrain/02094.jpg
#   inflating: resultTrain/02096.jpg
#   inflating: resultTrain/02097.jpg
#   inflating: resultTrain/02098.jpg
#   inflating: resultTrain/02100.jpg
#   inflating: resultTrain/02101.jpg
#   inflating: resultTrain/02103.jpg
#   inflating: resultTrain/02104.jpg
#   inflating: resultTrain/02106.jpg
#   inflating: resultTrain/02107.jpg
#   inflating: resultTrain/02108.jpg
#   inflating: resultTrain/02109.jpg
#   inflating: resultTrain/02114.jpg
#   inflating: resultTrain/02115.jpg
#   inflating: resultTrain/02116.jpg
#   inflating: resultTrain/02117.jpg
#   inflating: resultTrain/02118.jpg
#   inflating: resultTrain/02121.jpg
#   inflating: resultTrain/02122.jpg
#   inflating: resultTrain/02123.jpg
#   inflating: resultTrain/02125.jpg
#   inflating: resultTrain/02127.jpg
#   inflating: resultTrain/02128.jpg
#   inflating: resultTrain/02129.jpg
#   inflating: resultTrain/02130.jpg
#   inflating: resultTrain/02131.jpg
#   inflating: resultTrain/02132.jpg
#   inflating: resultTrain/02134.jpg
#   inflating: resultTrain/02137.jpg
#   inflating: resultTrain/02139.jpg
#   inflating: resultTrain/02140.jpg
#   inflating: resultTrain/02142.jpg
#   inflating: resultTrain/02144.jpg
#   inflating: resultTrain/02145.jpg
#   inflating: resultTrain/02146.jpg
#   inflating: resultTrain/02148.jpg
#   inflating: resultTrain/02149.jpg
#   inflating: resultTrain/02151.jpg
#   inflating: resultTrain/02152.jpg
#   inflating: resultTrain/02153.jpg
#   inflating: resultTrain/02154.jpg
#   inflating: resultTrain/02155.jpg
#   inflating: resultTrain/02156.jpg
#   inflating: resultTrain/02158.jpg
#   inflating: resultTrain/02159.jpg
#   inflating: resultTrain/02160.jpg
#   inflating: resultTrain/02161.jpg
#   inflating: resultTrain/02162.jpg
#   inflating: resultTrain/02163.jpg
#   inflating: resultTrain/02164.jpg
#   inflating: resultTrain/02165.jpg
#   inflating: resultTrain/02166.jpg
#   inflating: resultTrain/02167.jpg
#   inflating: resultTrain/02169.jpg
#   inflating: resultTrain/02170.jpg
#   inflating: resultTrain/02171.jpg
#   inflating: resultTrain/02174.jpg
#   inflating: resultTrain/02177.jpg
#   inflating: resultTrain/02178.jpg
#   inflating: resultTrain/02180.jpg
#   inflating: resultTrain/02183.jpg
#   inflating: resultTrain/02184.jpg
#   inflating: resultTrain/02185.jpg
#   inflating: resultTrain/02190.jpg
#   inflating: resultTrain/02191.jpg
#   inflating: resultTrain/02192.jpg
#   inflating: resultTrain/02193.jpg
#   inflating: resultTrain/02194.jpg
#   inflating: resultTrain/02195.jpg
#   inflating: resultTrain/02196.jpg
#   inflating: resultTrain/02198.jpg
#   inflating: resultTrain/02199.jpg
#   inflating: resultTrain/02200.jpg
#   inflating: resultTrain/02201.jpg
#   inflating: resultTrain/02203.jpg
#   inflating: resultTrain/02204.jpg
#   inflating: resultTrain/02205.jpg
#   inflating: resultTrain/02206.jpg
#   inflating: resultTrain/02207.jpg
#   inflating: resultTrain/02208.jpg
#   inflating: resultTrain/02211.jpg
#   inflating: resultTrain/02214.jpg
#   inflating: resultTrain/02216.jpg
#   inflating: resultTrain/02218.jpg
#   inflating: resultTrain/02219.jpg
#   inflating: resultTrain/02220.jpg
#   inflating: resultTrain/02221.jpg
#   inflating: resultTrain/02222.jpg
#   inflating: resultTrain/02223.jpg
#   inflating: resultTrain/02224.jpg
#   inflating: resultTrain/02225.jpg
#   inflating: resultTrain/02226.jpg
#   inflating: resultTrain/02228.jpg
#   inflating: resultTrain/02229.jpg
#   inflating: resultTrain/02230.jpg
#   inflating: resultTrain/02232.jpg
#   inflating: resultTrain/02233.jpg
#   inflating: resultTrain/02235.jpg
#   inflating: resultTrain/02236.jpg
#   inflating: resultTrain/02239.jpg
#   inflating: resultTrain/02240.jpg
#   inflating: resultTrain/02241.jpg
#   inflating: resultTrain/02242.jpg
#   inflating: resultTrain/02243.jpg
#   inflating: resultTrain/02244.jpg
#   inflating: resultTrain/02245.jpg
#   inflating: resultTrain/02247.jpg
#   inflating: resultTrain/02248.jpg
#   inflating: resultTrain/02249.jpg
#   inflating: resultTrain/02251.jpg
#   inflating: resultTrain/02253.jpg
#   inflating: resultTrain/02256.jpg
#   inflating: resultTrain/02258.jpg
#   inflating: resultTrain/02259.jpg
#   inflating: resultTrain/02261.jpg
#   inflating: resultTrain/02265.jpg
#   inflating: resultTrain/02266.jpg
#   inflating: resultTrain/02267.jpg
#   inflating: resultTrain/02268.jpg
#   inflating: resultTrain/02269.jpg
#   inflating: resultTrain/02270.jpg
#   inflating: resultTrain/02274.jpg
#   inflating: resultTrain/02279.jpg
#   inflating: resultTrain/02280.jpg
#   inflating: resultTrain/02281.jpg
#   inflating: resultTrain/02282.jpg
#   inflating: resultTrain/02283.jpg
#   inflating: resultTrain/02284.jpg
#   inflating: resultTrain/02285.jpg
#   inflating: resultTrain/02287.jpg
#   inflating: resultTrain/02289.jpg
#   inflating: resultTrain/02290.jpg
#   inflating: resultTrain/02291.jpg
#   inflating: resultTrain/02292.jpg
#   inflating: resultTrain/02293.jpg
#   inflating: resultTrain/02294.jpg
#   inflating: resultTrain/02295.jpg
#   inflating: resultTrain/02296.jpg
#   inflating: resultTrain/02297.jpg
#   inflating: resultTrain/02299.jpg
#   inflating: resultTrain/02300.jpg
#   inflating: resultTrain/02301.jpg
#   inflating: resultTrain/02302.jpg
#   inflating: resultTrain/02303.jpg
#   inflating: resultTrain/02304.jpg
#   inflating: resultTrain/02305.jpg
#   inflating: resultTrain/02306.jpg
#   inflating: resultTrain/02307.jpg
#   inflating: resultTrain/02308.jpg
#   inflating: resultTrain/02309.jpg
#   inflating: resultTrain/02310.jpg
#   inflating: resultTrain/02311.jpg
#   inflating: resultTrain/02314.jpg
#   inflating: resultTrain/02315.jpg
#   inflating: resultTrain/02316.jpg
#   inflating: resultTrain/02317.jpg
#   inflating: resultTrain/02318.jpg
#   inflating: resultTrain/02319.jpg
#   inflating: resultTrain/02321.jpg
#   inflating: resultTrain/02322.jpg
#   inflating: resultTrain/02323.jpg
#   inflating: resultTrain/02324.jpg
#   inflating: resultTrain/02325.jpg
#   inflating: resultTrain/02327.jpg
#   inflating: resultTrain/02330.jpg
#   inflating: resultTrain/02333.jpg
#   inflating: resultTrain/02334.jpg
#   inflating: resultTrain/02335.jpg
#   inflating: resultTrain/02336.jpg
#   inflating: resultTrain/02338.jpg
#   inflating: resultTrain/02339.jpg
#   inflating: resultTrain/02340.jpg
#   inflating: resultTrain/02341.jpg
#   inflating: resultTrain/02342.jpg
#   inflating: resultTrain/02344.jpg
#   inflating: resultTrain/02345.jpg
#   inflating: resultTrain/02346.jpg
#   inflating: resultTrain/02349.jpg
#   inflating: resultTrain/02350.jpg
#   inflating: resultTrain/02352.jpg
#   inflating: resultTrain/02353.jpg
#   inflating: resultTrain/02354.jpg
#   inflating: resultTrain/02355.jpg
#   inflating: resultTrain/02356.jpg
#   inflating: resultTrain/02357.jpg
#   inflating: resultTrain/02359.jpg
#   inflating: resultTrain/02362.jpg
#   inflating: resultTrain/02363.jpg
#   inflating: resultTrain/02366.jpg
#   inflating: resultTrain/02367.jpg
#   inflating: resultTrain/02368.jpg
#   inflating: resultTrain/02369.jpg
#   inflating: resultTrain/02372.jpg
#   inflating: resultTrain/02375.jpg
#   inflating: resultTrain/02377.jpg
#   inflating: resultTrain/02378.jpg
#   inflating: resultTrain/02379.jpg
#   inflating: resultTrain/02380.jpg
#   inflating: resultTrain/02382.jpg
#   inflating: resultTrain/02383.jpg
#   inflating: resultTrain/02384.jpg
#   inflating: resultTrain/02386.jpg
#   inflating: resultTrain/02387.jpg
#   inflating: resultTrain/02388.jpg
#   inflating: resultTrain/02391.jpg
#   inflating: resultTrain/02392.jpg
#   inflating: resultTrain/02393.jpg
#   inflating: resultTrain/02394.jpg
#   inflating: resultTrain/02395.jpg
#   inflating: resultTrain/02396.jpg
#   inflating: resultTrain/02399.jpg
#   inflating: resultTrain/02400.jpg
#   inflating: resultTrain/02401.jpg
#   inflating: resultTrain/02403.jpg
#   inflating: resultTrain/02404.jpg
#   inflating: resultTrain/02405.jpg
#   inflating: resultTrain/02406.jpg
#   inflating: resultTrain/02407.jpg
#   inflating: resultTrain/02409.jpg
#   inflating: resultTrain/02410.jpg
#   inflating: resultTrain/02413.jpg
#   inflating: resultTrain/02414.jpg
#   inflating: resultTrain/02415.jpg
#   inflating: resultTrain/02416.jpg
#   inflating: resultTrain/02417.jpg
#   inflating: resultTrain/02418.jpg
#   inflating: resultTrain/02419.jpg
#   inflating: resultTrain/02420.jpg
#   inflating: resultTrain/02421.jpg
#   inflating: resultTrain/02422.jpg
#   inflating: resultTrain/02424.jpg
#   inflating: resultTrain/02425.jpg
#   inflating: resultTrain/02426.jpg
#   inflating: resultTrain/02427.jpg
#   inflating: resultTrain/02428.jpg
#   inflating: resultTrain/02429.jpg
#   inflating: resultTrain/02431.jpg
#   inflating: resultTrain/02433.jpg
#   inflating: resultTrain/02434.jpg
#   inflating: resultTrain/02435.jpg
#   inflating: resultTrain/02437.jpg
#   inflating: resultTrain/02438.jpg
#   inflating: resultTrain/02439.jpg
#   inflating: resultTrain/02440.jpg
#   inflating: resultTrain/02441.jpg
#   inflating: resultTrain/02442.jpg
#   inflating: resultTrain/02443.jpg
#   inflating: resultTrain/02444.jpg
#   inflating: resultTrain/02448.jpg
#   inflating: resultTrain/02449.jpg
#   inflating: resultTrain/02450.jpg
#   inflating: resultTrain/02453.jpg
#   inflating: resultTrain/02454.jpg
#   inflating: resultTrain/02455.jpg
#   inflating: resultTrain/02457.jpg
#   inflating: resultTrain/02459.jpg
#   inflating: resultTrain/02460.jpg
#   inflating: resultTrain/02461.jpg
#   inflating: resultTrain/02463.jpg
#   inflating: resultTrain/02464.jpg
#   inflating: resultTrain/02465.jpg
#   inflating: resultTrain/02466.jpg
#   inflating: resultTrain/02467.jpg
#   inflating: resultTrain/02468.jpg
#   inflating: resultTrain/02469.jpg
#   inflating: resultTrain/02470.jpg
#   inflating: resultTrain/02472.jpg
#   inflating: resultTrain/02473.jpg
#   inflating: resultTrain/02474.jpg
#   inflating: resultTrain/02475.jpg
#   inflating: resultTrain/02476.jpg
#   inflating: resultTrain/02477.jpg
#   inflating: resultTrain/02478.jpg
#   inflating: resultTrain/02479.jpg
#   inflating: resultTrain/02480.jpg
#   inflating: resultTrain/02481.jpg
#   inflating: resultTrain/02482.jpg
#   inflating: resultTrain/02483.jpg
#   inflating: resultTrain/02484.jpg
#   inflating: resultTrain/02485.jpg
#   inflating: resultTrain/02486.jpg
#   inflating: resultTrain/02487.jpg
#   inflating: resultTrain/02489.jpg
#   inflating: resultTrain/02491.jpg
#   inflating: resultTrain/02493.jpg
#   inflating: resultTrain/02494.jpg
#   inflating: resultTrain/02495.jpg
#   inflating: resultTrain/02497.jpg
#   inflating: resultTrain/02499.jpg
#   inflating: resultTrain/02500.jpg
#   inflating: resultTrain/02503.jpg
#   inflating: resultTrain/02504.jpg
#   inflating: resultTrain/02508.jpg
#   inflating: resultTrain/02513.jpg
#   inflating: resultTrain/02516.jpg
#   inflating: resultTrain/02517.jpg
#   inflating: resultTrain/02518.jpg
#   inflating: resultTrain/02519.jpg
#   inflating: resultTrain/02520.jpg
#   inflating: resultTrain/02522.jpg
#   inflating: resultTrain/02523.jpg
#   inflating: resultTrain/02524.jpg
#   inflating: resultTrain/02526.jpg
#   inflating: resultTrain/02527.jpg
#   inflating: resultTrain/02528.jpg
#   inflating: resultTrain/02530.jpg
#   inflating: resultTrain/02532.jpg
#   inflating: resultTrain/02534.jpg
#   inflating: resultTrain/02535.jpg
#   inflating: resultTrain/02536.jpg
#   inflating: resultTrain/02537.jpg
#   inflating: resultTrain/02538.jpg
#   inflating: resultTrain/02540.jpg
#   inflating: resultTrain/02541.jpg
#   inflating: resultTrain/02543.jpg
#   inflating: resultTrain/02544.jpg
#   inflating: resultTrain/02546.jpg
#   inflating: resultTrain/02547.jpg
#   inflating: resultTrain/02548.jpg
#   inflating: resultTrain/02549.jpg
#   inflating: resultTrain/02550.jpg
#   inflating: resultTrain/02551.jpg
#   inflating: resultTrain/02553.jpg
#   inflating: resultTrain/02554.jpg
#   inflating: resultTrain/02555.jpg
#   inflating: resultTrain/02557.jpg
#   inflating: resultTrain/02558.jpg
#   inflating: resultTrain/02559.jpg
#   inflating: resultTrain/02560.jpg
#   inflating: resultTrain/02561.jpg
#   inflating: resultTrain/02565.jpg
#   inflating: resultTrain/02566.jpg
#   inflating: resultTrain/02567.jpg
#   inflating: resultTrain/02570.jpg
#   inflating: resultTrain/02572.jpg
#   inflating: resultTrain/02573.jpg
#   inflating: resultTrain/02574.jpg
#   inflating: resultTrain/02575.jpg
#   inflating: resultTrain/02576.jpg
#   inflating: resultTrain/02578.jpg
#   inflating: resultTrain/02579.jpg
#   inflating: resultTrain/02580.jpg
#   inflating: resultTrain/02581.jpg
#   inflating: resultTrain/02582.jpg
#   inflating: resultTrain/02584.jpg
#   inflating: resultTrain/02585.jpg
#   inflating: resultTrain/02586.jpg
#   inflating: resultTrain/02588.jpg
#   inflating: resultTrain/02589.jpg
#   inflating: resultTrain/02590.jpg
#   inflating: resultTrain/02591.jpg
#   inflating: resultTrain/02592.jpg
#   inflating: resultTrain/02594.jpg
#   inflating: resultTrain/02595.jpg
#   inflating: resultTrain/02597.jpg
#   inflating: resultTrain/02598.jpg
#   inflating: resultTrain/02601.jpg
#   inflating: resultTrain/02602.jpg
#   inflating: resultTrain/02606.jpg
#   inflating: resultTrain/02607.jpg
#   inflating: resultTrain/02608.jpg
#   inflating: resultTrain/02610.jpg
#   inflating: resultTrain/02612.jpg
#   inflating: resultTrain/02613.jpg
#   inflating: resultTrain/02615.jpg
#   inflating: resultTrain/02616.jpg
#   inflating: resultTrain/02617.jpg
#   inflating: resultTrain/02619.jpg
#   inflating: resultTrain/02620.jpg
#   inflating: resultTrain/02623.jpg
#   inflating: resultTrain/02624.jpg
#   inflating: resultTrain/02627.jpg
#   inflating: resultTrain/02628.jpg
#   inflating: resultTrain/02629.jpg
#   inflating: resultTrain/02631.jpg
#   inflating: resultTrain/02633.jpg
#   inflating: resultTrain/02634.jpg
#   inflating: resultTrain/02635.jpg
#   inflating: resultTrain/02636.jpg
#   inflating: resultTrain/02637.jpg
#   inflating: resultTrain/02638.jpg
#   inflating: resultTrain/02639.jpg
#   inflating: resultTrain/02640.jpg
#   inflating: resultTrain/02642.jpg
#   inflating: resultTrain/02643.jpg
#   inflating: resultTrain/02644.jpg
#   inflating: resultTrain/02647.jpg
#   inflating: resultTrain/02648.jpg
#   inflating: resultTrain/02649.jpg
#   inflating: resultTrain/02652.jpg
#   inflating: resultTrain/02653.jpg
#   inflating: resultTrain/02654.jpg
#   inflating: resultTrain/02655.jpg
#   inflating: resultTrain/02656.jpg
#   inflating: resultTrain/02657.jpg
#   inflating: resultTrain/02659.jpg
#   inflating: resultTrain/02660.jpg
#   inflating: resultTrain/02661.jpg
#   inflating: resultTrain/02662.jpg
#   inflating: resultTrain/02663.jpg
#   inflating: resultTrain/02664.jpg
#   inflating: resultTrain/02665.jpg
#   inflating: resultTrain/02666.jpg
#   inflating: resultTrain/02668.jpg
#   inflating: resultTrain/02669.jpg
#   inflating: resultTrain/02672.jpg
#   inflating: resultTrain/02673.jpg
#   inflating: resultTrain/02674.jpg
#   inflating: resultTrain/02675.jpg
#   inflating: resultTrain/02677.jpg
#   inflating: resultTrain/02678.jpg
#   inflating: resultTrain/02679.jpg
# ...
#   inflating: resultTrain/07414.jpg
#   inflating: resultTrain/07415.jpg
#   inflating: resultTrain/07416.jpg
#   inflating: resultTrain/07417.jpg
#   inflating: resultTrain/07418.jpg
#   inflating: resultTrain/07419.jpg
#   inflating: resultTrain/07421.jpg
#   inflating: resultTrain/07422.jpg
#   inflating: resultTrain/07424.jpg
#   inflating: resultTrain/07427.jpg
#   inflating: resultTrain/07428.jpg
#   inflating: resultTrain/07429.jpg
#   inflating: resultTrain/07430.jpg
#   inflating: resultTrain/07432.jpg
#   inflating: resultTrain/07434.jpg
#   inflating: resultTrain/07435.jpg
#   inflating: resultTrain/07437.jpg
#   inflating: resultTrain/07439.jpg
#   inflating: resultTrain/07440.jpg
#   inflating: resultTrain/07441.jpg
#   inflating: resultTrain/07442.jpg
#   inflating: resultTrain/07443.jpg
#   inflating: resultTrain/07444.jpg
#   inflating: resultTrain/07445.jpg
#   inflating: resultTrain/07446.jpg
#   inflating: resultTrain/07448.jpg
#   inflating: resultTrain/07449.jpg
#   inflating: resultTrain/07450.jpg
#   inflating: resultTrain/07451.jpg
#   inflating: resultTrain/07455.jpg
#   inflating: resultTrain/07456.jpg
#   inflating: resultTrain/07457.jpg
#   inflating: resultTrain/07458.jpg
#   inflating: resultTrain/07459.jpg
#   inflating: resultTrain/07460.jpg
#   inflating: resultTrain/07461.jpg
#   inflating: resultTrain/07462.jpg
#   inflating: resultTrain/07463.jpg
#   inflating: resultTrain/07464.jpg
#   inflating: resultTrain/07466.jpg
#   inflating: resultTrain/07467.jpg
#   inflating: resultTrain/07468.jpg
#   inflating: resultTrain/07469.jpg
#   inflating: resultTrain/07470.jpg
#   inflating: resultTrain/07471.jpg
#   inflating: resultTrain/07472.jpg
#   inflating: resultTrain/07473.jpg
#   inflating: resultTrain/07474.jpg
#   inflating: resultTrain/07475.jpg
#   inflating: resultTrain/07476.jpg
#   inflating: resultTrain/07479.jpg
#   inflating: resultTrain/07480.jpg
#   inflating: resultTrain/07481.jpg
#   inflating: resultTrain/07482.jpg
#   inflating: resultTrain/07483.jpg
#   inflating: resultTrain/07484.jpg
#   inflating: resultTrain/07485.jpg
#   inflating: resultTrain/07486.jpg
#   inflating: resultTrain/07487.jpg
#   inflating: resultTrain/07489.jpg
#   inflating: resultTrain/07491.jpg
#   inflating: resultTrain/07493.jpg
#   inflating: resultTrain/07494.jpg
#   inflating: resultTrain/07495.jpg
#   inflating: resultTrain/07498.jpg
#   inflating: resultTrain/07499.jpg
#   inflating: resultTrain/07500.jpg
#   inflating: resultTrain/07501.jpg
#   inflating: resultTrain/07502.jpg
#   inflating: resultTrain/07503.jpg
#   inflating: resultTrain/07504.jpg
#   inflating: resultTrain/07505.jpg
#   inflating: resultTrain/07506.jpg
#   inflating: resultTrain/07507.jpg
#   inflating: resultTrain/07510.jpg
#   inflating: resultTrain/07511.jpg
#   inflating: resultTrain/07512.jpg
#   inflating: resultTrain/07513.jpg
#   inflating: resultTrain/07515.jpg
#   inflating: resultTrain/07516.jpg
#   inflating: resultTrain/07517.jpg
#   inflating: resultTrain/07518.jpg
#   inflating: resultTrain/07519.jpg
#   inflating: resultTrain/07520.jpg
#   inflating: resultTrain/07521.jpg
#   inflating: resultTrain/07522.jpg
#   inflating: resultTrain/07525.jpg
#   inflating: resultTrain/07526.jpg
#   inflating: resultTrain/07529.jpg
#   inflating: resultTrain/07533.jpg
#   inflating: resultTrain/07534.jpg
#   inflating: resultTrain/07535.jpg
#   inflating: resultTrain/07537.jpg
#   inflating: resultTrain/07538.jpg
#   inflating: resultTrain/07539.jpg
#   inflating: resultTrain/07541.jpg
#   inflating: resultTrain/07542.jpg
#   inflating: resultTrain/07543.jpg
#   inflating: resultTrain/07545.jpg
#   inflating: resultTrain/07546.jpg
#   inflating: resultTrain/07548.jpg
#   inflating: resultTrain/07550.jpg
#   inflating: resultTrain/07551.jpg
#   inflating: resultTrain/07553.jpg
#   inflating: resultTrain/07554.jpg
#   inflating: resultTrain/07555.jpg
#   inflating: resultTrain/07556.jpg
#   inflating: resultTrain/07557.jpg
#   inflating: resultTrain/07558.jpg
#   inflating: resultTrain/07559.jpg
#   inflating: resultTrain/07561.jpg
#   inflating: resultTrain/07562.jpg
#   inflating: resultTrain/07563.jpg
#   inflating: resultTrain/07565.jpg
#   inflating: resultTrain/07566.jpg
#   inflating: resultTrain/07567.jpg
#   inflating: resultTrain/07570.jpg
#   inflating: resultTrain/07571.jpg
#   inflating: resultTrain/07572.jpg
#   inflating: resultTrain/07574.jpg
#   inflating: resultTrain/07575.jpg
#   inflating: resultTrain/07577.jpg
#   inflating: resultTrain/07579.jpg
#   inflating: resultTrain/07580.jpg
#   inflating: resultTrain/07581.jpg
#   inflating: resultTrain/07582.jpg
#   inflating: resultTrain/07583.jpg
#   inflating: resultTrain/07584.jpg
#   inflating: resultTrain/07588.jpg
#   inflating: resultTrain/07590.jpg
#   inflating: resultTrain/07593.jpg
#   inflating: resultTrain/07594.jpg
#   inflating: resultTrain/07595.jpg
#   inflating: resultTrain/07596.jpg
#   inflating: resultTrain/07597.jpg
#   inflating: resultTrain/07598.jpg
#   inflating: resultTrain/07599.jpg
#   inflating: resultTrain/07600.jpg
#   inflating: resultTrain/07601.jpg
#   inflating: resultTrain/07602.jpg
#   inflating: resultTrain/07609.jpg
#   inflating: resultTrain/07611.jpg
#   inflating: resultTrain/07612.jpg
#   inflating: resultTrain/07614.jpg
#   inflating: resultTrain/07615.jpg
#   inflating: resultTrain/07616.jpg
#   inflating: resultTrain/07617.jpg
#   inflating: resultTrain/07618.jpg
#   inflating: resultTrain/07620.jpg
#   inflating: resultTrain/07621.jpg
#   inflating: resultTrain/07622.jpg
#   inflating: resultTrain/07623.jpg
#   inflating: resultTrain/07624.jpg
#   inflating: resultTrain/07625.jpg
#   inflating: resultTrain/07627.jpg
#   inflating: resultTrain/07628.jpg
#   inflating: resultTrain/07629.jpg
#   inflating: resultTrain/07631.jpg
#   inflating: resultTrain/07632.jpg
#   inflating: resultTrain/07633.jpg
#   inflating: resultTrain/07634.jpg
#   inflating: resultTrain/07635.jpg
#   inflating: resultTrain/07636.jpg
#   inflating: resultTrain/07637.jpg
#   inflating: resultTrain/07638.jpg
#   inflating: resultTrain/07639.jpg
#   inflating: resultTrain/07640.jpg
#   inflating: resultTrain/07641.jpg
#   inflating: resultTrain/07643.jpg
#   inflating: resultTrain/07644.jpg
#   inflating: resultTrain/07645.jpg
#   inflating: resultTrain/07646.jpg
#   inflating: resultTrain/07649.jpg
#   inflating: resultTrain/07650.jpg
#   inflating: resultTrain/07651.jpg
#   inflating: resultTrain/07653.jpg
#   inflating: resultTrain/07655.jpg
#   inflating: resultTrain/07656.jpg
#   inflating: resultTrain/07657.jpg
#   inflating: resultTrain/07658.jpg
#   inflating: resultTrain/07659.jpg
#   inflating: resultTrain/07660.jpg
#   inflating: resultTrain/07661.jpg
#   inflating: resultTrain/07663.jpg
#   inflating: resultTrain/07664.jpg
#   inflating: resultTrain/07665.jpg
#   inflating: resultTrain/07667.jpg
#   inflating: resultTrain/07668.jpg
#   inflating: resultTrain/07669.jpg
#   inflating: resultTrain/07670.jpg
#   inflating: resultTrain/07672.jpg
#   inflating: resultTrain/07673.jpg
#   inflating: resultTrain/07675.jpg
#   inflating: resultTrain/07677.jpg
#   inflating: resultTrain/07678.jpg
#   inflating: resultTrain/07679.jpg
#   inflating: resultTrain/07680.jpg
#   inflating: resultTrain/07681.jpg
#   inflating: resultTrain/07682.jpg
#   inflating: resultTrain/07683.jpg
#   inflating: resultTrain/07685.jpg
#   inflating: resultTrain/07686.jpg
#   inflating: resultTrain/07687.jpg
#   inflating: resultTrain/07688.jpg
#   inflating: resultTrain/07689.jpg
#   inflating: resultTrain/07690.jpg
#   inflating: resultTrain/07691.jpg
#   inflating: resultTrain/07694.jpg
#   inflating: resultTrain/07695.jpg
#   inflating: resultTrain/07696.jpg
#   inflating: resultTrain/07698.jpg
#   inflating: resultTrain/07699.jpg
#   inflating: resultTrain/07700.jpg
#   inflating: resultTrain/07701.jpg
#   inflating: resultTrain/07703.jpg
#   inflating: resultTrain/07704.jpg
#   inflating: resultTrain/07705.jpg
#   inflating: resultTrain/07706.jpg
#   inflating: resultTrain/07707.jpg
#   inflating: resultTrain/07708.jpg
#   inflating: resultTrain/07710.jpg
#   inflating: resultTrain/07711.jpg
#   inflating: resultTrain/07712.jpg
#   inflating: resultTrain/07715.jpg
#   inflating: resultTrain/07720.jpg
#   inflating: resultTrain/07722.jpg
#   inflating: resultTrain/07723.jpg
#   inflating: resultTrain/07724.jpg
#   inflating: resultTrain/07725.jpg
#   inflating: resultTrain/07728.jpg
#   inflating: resultTrain/07730.jpg
#   inflating: resultTrain/07731.jpg
#   inflating: resultTrain/07732.jpg
#   inflating: resultTrain/07734.jpg
#   inflating: resultTrain/07735.jpg
#   inflating: resultTrain/07736.jpg
#   inflating: resultTrain/07737.jpg
#   inflating: resultTrain/07739.jpg
#   inflating: resultTrain/07740.jpg
#   inflating: resultTrain/07741.jpg
#   inflating: resultTrain/07742.jpg
#   inflating: resultTrain/07744.jpg
#   inflating: resultTrain/07745.jpg
#   inflating: resultTrain/07746.jpg
#   inflating: resultTrain/07747.jpg
#   inflating: resultTrain/07748.jpg
#   inflating: resultTrain/07749.jpg
#   inflating: resultTrain/07750.jpg
#   inflating: resultTrain/07751.jpg
#   inflating: resultTrain/07752.jpg
#   inflating: resultTrain/07753.jpg
#   inflating: resultTrain/07754.jpg
#   inflating: resultTrain/07760.jpg
#   inflating: resultTrain/07762.jpg
#   inflating: resultTrain/07763.jpg
#   inflating: resultTrain/07764.jpg
#   inflating: resultTrain/07765.jpg
#   inflating: resultTrain/07766.jpg
#   inflating: resultTrain/07771.jpg
#   inflating: resultTrain/07772.jpg
#   inflating: resultTrain/07773.jpg
#   inflating: resultTrain/07774.jpg
#   inflating: resultTrain/07775.jpg
#   inflating: resultTrain/07777.jpg
#   inflating: resultTrain/07780.jpg
#   inflating: resultTrain/07782.jpg
#   inflating: resultTrain/07783.jpg
#   inflating: resultTrain/07784.jpg
#   inflating: resultTrain/07785.jpg
#   inflating: resultTrain/07786.jpg
#   inflating: resultTrain/07787.jpg
#   inflating: resultTrain/07788.jpg
#   inflating: resultTrain/07789.jpg
#   inflating: resultTrain/07790.jpg
#   inflating: resultTrain/07791.jpg
#   inflating: resultTrain/07792.jpg
#   inflating: resultTrain/07795.jpg
#   inflating: resultTrain/07796.jpg
#   inflating: resultTrain/07797.jpg
#   inflating: resultTrain/07798.jpg
#   inflating: resultTrain/07799.jpg
#   inflating: resultTrain/07800.jpg
#   inflating: resultTrain/07801.jpg
#   inflating: resultTrain/07802.jpg
#   inflating: resultTrain/07803.jpg
#   inflating: resultTrain/07804.jpg
#   inflating: resultTrain/07805.jpg
#   inflating: resultTrain/07807.jpg
#   inflating: resultTrain/07809.jpg
#   inflating: resultTrain/07810.jpg
#   inflating: resultTrain/07811.jpg
#   inflating: resultTrain/07812.jpg
#   inflating: resultTrain/07814.jpg
#   inflating: resultTrain/07815.jpg
#   inflating: resultTrain/07816.jpg
#   inflating: resultTrain/07817.jpg
#   inflating: resultTrain/07818.jpg
#   inflating: resultTrain/07819.jpg
#   inflating: resultTrain/07820.jpg
#   inflating: resultTrain/07821.jpg
#   inflating: resultTrain/07822.jpg
#   inflating: resultTrain/07824.jpg
#   inflating: resultTrain/07825.jpg
#   inflating: resultTrain/07826.jpg
#   inflating: resultTrain/07827.jpg
#   inflating: resultTrain/07828.jpg
#   inflating: resultTrain/07830.jpg
#   inflating: resultTrain/07831.jpg
#   inflating: resultTrain/07833.jpg
#   inflating: resultTrain/07834.jpg
#   inflating: resultTrain/07835.jpg
#   inflating: resultTrain/07836.jpg
#   inflating: resultTrain/07838.jpg
#   inflating: resultTrain/07839.jpg
#   inflating: resultTrain/07840.jpg
#   inflating: resultTrain/07841.jpg
#   inflating: resultTrain/07843.jpg
#   inflating: resultTrain/07844.jpg
#   inflating: resultTrain/07845.jpg
#   inflating: resultTrain/07846.jpg
#   inflating: resultTrain/07847.jpg
#   inflating: resultTrain/07849.jpg
#   inflating: resultTrain/07850.jpg
#   inflating: resultTrain/07851.jpg
#   inflating: resultTrain/07852.jpg
#   inflating: resultTrain/07855.jpg
#   inflating: resultTrain/07858.jpg
#   inflating: resultTrain/07859.jpg
#   inflating: resultTrain/07864.jpg
#   inflating: resultTrain/07865.jpg
#   inflating: resultTrain/07866.jpg
#   inflating: resultTrain/07867.jpg
#   inflating: resultTrain/07868.jpg
#   inflating: resultTrain/07871.jpg
#   inflating: resultTrain/07873.jpg
#   inflating: resultTrain/07875.jpg
#   inflating: resultTrain/07876.jpg
#   inflating: resultTrain/07877.jpg
#   inflating: resultTrain/07878.jpg
#   inflating: resultTrain/07882.jpg
#   inflating: resultTrain/07883.jpg
#   inflating: resultTrain/07885.jpg
#   inflating: resultTrain/07887.jpg
#   inflating: resultTrain/07890.jpg
#   inflating: resultTrain/07892.jpg
#   inflating: resultTrain/07893.jpg
#   inflating: resultTrain/07894.jpg
#   inflating: resultTrain/07895.jpg
#   inflating: resultTrain/07897.jpg
#   inflating: resultTrain/07898.jpg
#   inflating: resultTrain/07899.jpg
#   inflating: resultTrain/07900.jpg
#   inflating: resultTrain/07902.jpg
#   inflating: resultTrain/07903.jpg
#   inflating: resultTrain/07905.jpg
#   inflating: resultTrain/07906.jpg
#   inflating: resultTrain/07908.jpg
#   inflating: resultTrain/07909.jpg
#   inflating: resultTrain/07910.jpg
#   inflating: resultTrain/07913.jpg
#   inflating: resultTrain/07914.jpg
#   inflating: resultTrain/07916.jpg
#   inflating: resultTrain/07917.jpg
#   inflating: resultTrain/07919.jpg
#   inflating: resultTrain/07921.jpg
#   inflating: resultTrain/07923.jpg
#   inflating: resultTrain/07924.jpg
#   inflating: resultTrain/07925.jpg
#   inflating: resultTrain/07926.jpg
#   inflating: resultTrain/07927.jpg
#   inflating: resultTrain/07928.jpg
#   inflating: resultTrain/07932.jpg
#   inflating: resultTrain/07933.jpg
#   inflating: resultTrain/07936.jpg
#   inflating: resultTrain/07939.jpg
#   inflating: resultTrain/07940.jpg
#   inflating: resultTrain/07941.jpg
#   inflating: resultTrain/07942.jpg
#   inflating: resultTrain/07946.jpg
#   inflating: resultTrain/07950.jpg
#   inflating: resultTrain/07951.jpg
#   inflating: resultTrain/07952.jpg
#   inflating: resultTrain/07953.jpg
#   inflating: resultTrain/07954.jpg
#   inflating: resultTrain/07956.jpg
#   inflating: resultTrain/07957.jpg
#   inflating: resultTrain/07958.jpg
#   inflating: resultTrain/07960.jpg
#   inflating: resultTrain/07961.jpg
#   inflating: resultTrain/07963.jpg
#   inflating: resultTrain/07964.jpg
#   inflating: resultTrain/07965.jpg
#   inflating: resultTrain/07966.jpg
#   inflating: resultTrain/07967.jpg
#   inflating: resultTrain/07968.jpg
#   inflating: resultTrain/07969.jpg
#   inflating: resultTrain/07973.jpg
#   inflating: resultTrain/07974.jpg
#   inflating: resultTrain/07976.jpg
#   inflating: resultTrain/07978.jpg
#   inflating: resultTrain/07979.jpg
#   inflating: resultTrain/07980.jpg
#   inflating: resultTrain/07981.jpg
#   inflating: resultTrain/07982.jpg
#   inflating: resultTrain/07983.jpg
#   inflating: resultTrain/07984.jpg
#   inflating: resultTrain/07985.jpg
#   inflating: resultTrain/07986.jpg
#   inflating: resultTrain/07987.jpg
#   inflating: resultTrain/07988.jpg
#   inflating: resultTrain/07990.jpg
#   inflating: resultTrain/07993.jpg
#   inflating: resultTrain/07996.jpg
#   inflating: resultTrain/07998.jpg
#   inflating: resultTrain/07999.jpg
#   inflating: resultTrain/08000.jpg
# C1-P1_Dev	C1-P1_TrainLabel  data_small.zip  resultDev    train.csv
# C1-P1_DevLabel	crop.py		  data.zip	  resultTrain  vgg.pth
# C1-P1_Train	data_small	  dev.csv	  sample_data  yolo_data.zip

# %%
import torch
import torchvision
import torch.nn as nn  # All neural network modules, nn.Linear, nn.Conv2d, BatchNorm, Loss functions
import torch.optim as optim  # For all Optimization algorithms, SGD, Adam, etc.
import torch.nn.functional as F  # All functions that don't have any parameters
from torch.utils.data import (
    DataLoader, Dataset
)  # Gives easier dataset managment and creates mini batches
import torchvision.datasets as datasets  # Has standard datasets we can import in a nice way
import torchvision.transforms as transforms  # Transformations we can perform on our dataset
import torchvision.io as tvio
import pandas as pd
import numpy as np
import os
import sys

# %%
# !nvidia-smi
# Out:
# Wed Dec 14 11:56:00 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
torch.cuda.empty_cache()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Hyperparameters
num_classes = 3
learning_rate = 1e-3
batch_size = 100
num_epochs = 100
early_stop = 10

# %% [markdown]
# # VGG-16 Model

# %%
# Load pretrain model & modify it
model = torchvision.models.vgg16(pretrained=True)

# If you want to do finetuning then set requires_grad = False
# Remove these two lines if you want to train entire model,
# and only want to load the pretrain weights.
for param in model.parameters():
    param.requires_grad = True

model.classifier = nn.Sequential(
    nn.Linear(512 * 7 * 7, 512),
    nn.Dropout(p=0.25),
    nn.Linear(512, 256),
    nn.Dropout(p=0.25),
    nn.BatchNorm1d(256),
    nn.Linear(256, num_classes)
)
model.to(device)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): Linear(in_features=256, out_features=3, bias=True)
#   )
# )

# %%
from torchsummary import summary

summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                  [-1, 512]      12,845,568
#           Dropout-34                  [-1, 512]               0
#            Linear-35                  [-1, 256]         131,328
#           Dropout-36                  [-1, 256]               0
#       BatchNorm1d-37                  [-1, 256]             512
#            Linear-38                    [-1, 3]             771
# ================================================================
# Total params: 27,692,867
# Trainable params: 27,692,867
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.60
# Params size (MB): 105.64
# Estimated Total Size (MB): 324.81
# ----------------------------------------------------------------

# %%
transform = torchvision.transforms.Compose([
    #轉成tensor格式
    # torchvision.transforms.ToTensor(),
    #將短邊等比放大成224
    torchvision.transforms.Resize(224),
    #裁切多於的部分
    torchvision.transforms.CenterCrop(224),
    #正規化
    torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])])

# %%
class CustomImageDataset(Dataset):
  def __init__(self, annotations_file, img_dir, transform=None):
    self.img_labels = pd.read_csv(annotations_file)
    self.img_dir = img_dir
    self.transform = transform
    unique, inverse = np.unique(self.img_labels.iloc[:, 1], return_inverse=True)
    self.onehot_list = np.eye(unique.shape[0])[inverse]

  def __len__(self):
    return len(self.img_labels)

  def __getitem__(self, idx):
    img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
    image = tvio.read_image(img_path) #讀取圖片
    label = self.onehot_list[idx] #第0列=檔名，第1列=label
    image = self.transform(image.float())
    return image, label

train_dataset = CustomImageDataset('train.csv', 'resultTrain', transform=transform)
dev_dataset = CustomImageDataset('dev.csv', 'resultDev', transform=transform)

# %%
#load data
train_num = int(len(train_dataset)*0.7)
valid_num = len(train_dataset)-train_num
train_set, valid_set = torch.utils.data.random_split(train_dataset, [train_num, valid_num])

train_loader = DataLoader(train_set, batch_size = batch_size, shuffle = True)
valid_loader = DataLoader(valid_set, batch_size = batch_size, shuffle = False)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Define training
def train(train_loader, dev_loader, model, device):
  # settings
  path = 'vgg-yolo.pth'
  
  epoch = 0
  min = sys.maxsize
  early_stop_cnt = 0
  
  while epoch < num_epochs:
    model.train()
    for i, (x,y) in enumerate(train_loader):
        optimizer.zero_grad()
        x, y = x.to(device), y.to(device)
        pred = model(x)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()

    if dev_loader is not None:
      dev_loss = dev(dev_loader, model, device)
      if dev_loss < min:
        torch.save(model, path)
        min = dev_loss
        print('epoch {}: loss = {}'.format(epoch+1, min))
        early_stop_cnt = 0
      else:
        early_stop_cnt += 1
    epoch += 1
    if early_stop_cnt > early_stop:
      break

  print('Finished training after {} epochs'.format(epoch))

# Define validation
def dev(dev_loader, model, device):
    model.eval()
    total_loss = 0
    for x, y in dev_loader:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            pred = model(x)
            mse_loss = criterion(pred, y)
        total_loss += mse_loss.detach().cpu().item()*len(x)
    
    return total_loss / len(dev_loader.dataset)

# %%
train(train_loader, valid_loader, model, device)
# Out:
# epoch 1: loss = 0.9350061795958646
# epoch 3: loss = 0.6591914582287015
# epoch 4: loss = 0.574328299278853
# epoch 9: loss = 0.5588553527393145
# epoch 11: loss = 0.5507558862417067
# Finished training after 22 epochs

# %%
test_loader = DataLoader(dev_dataset, batch_size = batch_size, shuffle = False)

# %%
# Define testing
def test(test_loader, model, device):
  model.eval()
  pred_list = []
  test_y = []
  for x, y in test_loader:
    x = x.to(device)
    with torch.no_grad():
      pred = model(x)
      pred_list.append(pred.detach().cpu())

  pred_list = torch.cat(pred_list, dim=0).numpy()
  print("Done testing")
  return pred_list

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0) # only difference

# %%
# Testing
vgg_model = torch.load('vgg-yolo.pth').to(device)
test_pred = test(test_loader, vgg_model, device)
res_list = []
for test in test_pred:
    res = softmax(test)
    x = np.zeros(3)
    x[np.argmax(res)] = 1
    res_list.append(x)
# Out:
# Done testing

# %%
test_y_list = []
for x, batch_y in test_loader:
  for y in batch_y:
    test_y_list.append(y)

# %%
total = 0
for i in range(len(res_list)):
    if np.argmax(res_list[i]) == np.argmax(test_y_list[i]):
        total += 1
print('accuracy', total/len(res_list))
# Out:
# accuracy 0.76375

# %%
for idx, each in enumerate(test_y_list):
  test_y_list[idx] = each.tolist()
# Out:
# <class 'list'>

# %%
from sklearn.metrics import f1_score

# %%
f1_score(test_y_list, res_list, average='micro')
# Out:
# 0.76375

# %%
f1_score(test_y_list, res_list, average='macro')
# Out:
# 0.7678865511182584

# %%
f1_score(test_y_list, res_list, average=None)
# Out:
# array([0.7985348 , 0.67595819, 0.82916667])

# %% [markdown]
# #VGG-16 Model with YOLO

# %%
train_dataset = CustomImageDataset('train.csv', 'resultTrain', transform=transform)
dev_dataset = CustomImageDataset('dev.csv', 'resultDev', transform=transform)

# %%
#load data
train_num = int(len(train_dataset)*0.7)
valid_num = len(train_dataset)-train_num
train_set, valid_set = torch.utils.data.random_split(train_dataset, [train_num, valid_num])

train_loader = DataLoader(train_set, batch_size = batch_size, shuffle = True)
valid_loader = DataLoader(valid_set, batch_size = batch_size, shuffle = False)

# %%
# Define training
def train(train_loader, dev_loader, model, device):
  # settings
  path = 'vgg-yolo.pth'
  
  epoch = 0
  min = sys.maxsize
  early_stop_cnt = 0
  
  while epoch < num_epochs:
    model.train()
    for i, (x,y) in enumerate(train_loader):
        optimizer.zero_grad()
        x, y = x.to(device), y.to(device)
        pred = model(x)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()

    if dev_loader is not None:
      dev_loss = dev(dev_loader, model, device)
      if dev_loss < min:
        torch.save(model, path)
        min = dev_loss
        print('epoch {}: loss = {}'.format(epoch+1, min))
        early_stop_cnt = 0
      else:
        early_stop_cnt += 1
    epoch += 1
    if early_stop_cnt > early_stop:
      break

  print('Finished training after {} epochs'.format(epoch))

# Define validation
def dev(dev_loader, model, device):
    model.eval()
    total_loss = 0
    for x, y in dev_loader:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            pred = model(x)
            mse_loss = criterion(pred, y)
        total_loss += mse_loss.detach().cpu().item()*len(x)
    
    return total_loss / len(dev_loader.dataset)

# %%
train(train_loader, valid_loader, model, device)

# %%
test_loader = DataLoader(dev_dataset, batch_size = batch_size, shuffle = False)

# %%
# Define testing
def test(test_loader, model, device):
  model.eval()
  pred_list = []
  test_y = []
  for x, y in test_loader:
    x = x.to(device)
    with torch.no_grad():
      pred = model(x)
      pred_list.append(pred.detach().cpu())

  pred_list = torch.cat(pred_list, dim=0).numpy()
  print("Done testing")
  return pred_list

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0) # only difference

# %%
# Testing
vgg_model = torch.load('vgg-yolo.pth').to(device)
test_pred = test(test_loader, vgg_model, device)
res_list = []
for test in test_pred:
    res = softmax(test)
    x = np.zeros(3)
    x[np.argmax(res)] = 1
    res_list.append(x)

# %%
test_y_list = []
for x, batch_y in test_loader:
  for y in batch_y:
    test_y_list.append(y)

# %%
total = 0
for i in range(len(res_list)):
    if np.argmax(res_list[i]) == np.argmax(test_y_list[i]):
        total += 1
print('accuracy', total/len(res_list))

# %%
for idx, each in enumerate(test_y_list):
  test_y_list[idx] = each.tolist()

# %%
f1_score(test_y_list, res_list, average='micro')

# %%
f1_score(test_y_list, res_list, average='macro')

# %%
f1_score(test_y_list, res_list, average=None)
